# %%
import pandas as pd
from datetime import datetime as dt, timedelta
import matplotlib.pyplot as plt
import json

df = pd.read_csv(f"csv/inout_member_hist.csv")


fig, ax = plt.subplots()

date = [ str(x) for x in df["date"]]

print(date)
counts = [ len(json.loads(x)) for x in df["in"]]
print(counts)
out_df = pd.DataFrame.from_dict(df["out"])
# counts = len(in_df.index)
# bar_labels = ['red', 'blue', '_red', 'orange']
# bar_colors = ['tab:red', 'tab:blue', 'tab:red', 'tab:orange']
ax.bar(date, counts)

ax.set_ylabel('In/Out member')
ax.set_title('In/Out member')
ax.legend(title='In/Out member')

plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# 0    20231016
# 1    20231017
# Name: date, dtype: int64
# [3, 3]
