# %%
import pandas as pd
from datetime import datetime as dt, timedelta
import matplotlib.pyplot as plt
import json

df = pd.read_csv(f"csv/inout_member_hist.csv")


fig, ax = plt.subplots()

date = df["date"]
print(date)
in_df = df["in"].to_dict()
print(in_df)
counts = 0
print(counts)
out_df = pd.DataFrame.from_dict(df["out"])
# counts = len(in_df.index)
# bar_labels = ['red', 'blue', '_red', 'orange']
# bar_colors = ['tab:red', 'tab:blue', 'tab:red', 'tab:orange']
ax.bar(date, counts)

ax.set_ylabel('In/Out member')
ax.set_title('In/Out member')
ax.legend(title='In/Out member')

plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# 0    20231015
# 1    20231016
# Name: date, dtype: int64
# {0: "{'user_id': {13: 5773295420, 14: 1763498590, 15: 5620525872}, 'user_name': {13: 'bnormi', 14: nan, 15: 'NuttaphonN'}, 'ind': {13: 'left_only', 14: 'left_only', 15: 'left_only'}}", 1: "{'user_id': {14: 1763498590, 15: 5620525872}, 'user_name': {14: nan, 15: 'NuttaphonN'}, 'ind': { 14: 'left_only', 15: 'left_only'}}"}
# 0
